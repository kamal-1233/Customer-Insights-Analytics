# %% [markdown]
# # EDA

# %%
# Import Panda Library

import pandas as pd

# %%
# Python Package Installer

# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#importing the Dataset
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0            2701   22  Female        T-shirt     Clothing
# 1             521   51    Male     Sunglasses  Accessories
# 2            3157   18  Female          Shirt     Clothing
# 3            1687   22    Male         Gloves  Accessories
# 4            2929   40  Female        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 0                      68.0      California   XL   Olive  Winter
# 1                      84.0  South Carolina    M   White  Spring
# 2                      50.0         Montana    M   Black  Winter
# 3                      75.0        Illinois    L     Red    Fall
# 4                      80.0         Alabama    L  Yellow  Spring
# ...                     ...             ...  ...     ...     ...
# 5045                   56.0        Arkansas    M   Green  Winter
# 5046                   53.0            Iowa    M    Gold  Spring
# 5047                   27.0    North Dakota    M   White  Summer
# 5048                   52.0        Maryland    L    Gold  Summer
# 5049                   71.0           Maine    M    Cyan  Summer
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.2                  No        Standard               No
# 1               3.9                 Yes   Free Shipping              Yes
# 2               3.1                  No  2-Day Shipping               No
# 3               4.2                  No    Store Pickup               No
# 4               3.6                  No    Store Pickup               No
# ...             ...                 ...             ...              ...
# 5045            3.4                 Yes    Next Day Air              Yes
# 5046            3.4                  No        Standard               No
# 5047            3.2                  No        Standard               No
# 5048            4.6                  No        Standard               No
# 5049            3.3                  No   Free Shipping               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5050 rows x 17 columns]

# %%
# df.head() for top 5 lines and df.tail() bottom 5 lines if you need more rows (19) enter 
# value in like (19) this

# %%
df.shape # for check length of row and columns
# Out:
# (5050, 17)

# %%
df.describe() #for show numeric columns and if we do this(include="all") the show all columns
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4494.000000    4449.000000
# mean   2519.570891    44.150495             144.765236       3.668195
# std    1470.402964    15.282328             275.590101       0.865357
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.info() #give complete details for database

# %%
df.isnull().sum() # find null value from dataset
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
df['Item Purchased'] #for check any header data
# Out:
# 0          T-shirt
# 1       Sunglasses
# 2            Shirt
# 3           Gloves
# 4          Jewelry
#            ...
# 5045        Hoodie
# 5046      Backpack
# 5047         Skirt
# 5048      Sneakers
# 5049        Blouse
# Name: Item Purchased, Length: 5050, dtype: object

# %%
df['Item Purchased'].unique()
# Out:
# array(['T-shirt', 'Sunglasses', 'Shirt', 'Gloves', 'Jewelry', 'Shorts',
#        'Hat', 'Handbag', 'Shoes', 'Coat', 'Laptop', 'Hoodie', 'Phone',
#        'Jacket', 'Pants', 'Backpack', 'Socks', 'Jeans', 'Bag', 'Belt',
#        'Watch', 'Headphones', 'Blouse', 'Sandals', 'Skirt', 'Sweater',
#        'Scarf', 'Sneakers', 'Boots', 'Dress'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Accessories', 'Outerwear', 'Electronics', 'Footwear'],
#       dtype=object)

# %%
df.groupby('Category')['Item Purchased'].unique() #add group to check category of projects
# Out:
# Category
# Accessories    [Sunglasses, Gloves, Jewelry, Hat, Handbag, Ph...
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone,...
# Electronics    [Laptop, Phone, Watch, Bag, Shoes, Shirt, Head...
# Footwear                       [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                         [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
pd.set_option('display.max_colwidth',None) #for adjust size to view all data
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
correct_mapping = {
    # Clothing
    "T-shirt": "Clothing", "Shirt": "Clothing", "Shorts": "Clothing",
    "Hoodie": "Clothing", "Pants": "Clothing", "Socks": "Clothing",
    "Jeans": "Clothing", "Blouse": "Clothing", "Skirt": "Clothing",
    "Sweater": "Clothing", "Dress": "Clothing",

    # Accessories
    "Sunglasses": "Accessories", "Gloves": "Accessories",
    "Jewelry": "Accessories", "Hat": "Accessories",
    "Handbag": "Accessories", "Backpack": "Accessories",
    "Belt": "Accessories", "Scarf": "Accessories",
    "Bag": "Accessories",

    # Electronics
    "Laptop": "Electronics", "Phone": "Electronics",
    "Headphones": "Electronics", "Watch": "Electronics",

    # Footwear
    "Shoes": "Footwear", "Sandals": "Footwear",
    "Sneakers": "Footwear", "Boots": "Footwear",

    # Outerwear
    "Coat": "Outerwear", "Jacket": "Outerwear"
}

# %%
correct_mapping
# Out:
# {'T-shirt': 'Clothing',
#  'Shirt': 'Clothing',
#  'Shorts': 'Clothing',
#  'Hoodie': 'Clothing',
#  'Pants': 'Clothing',
#  'Socks': 'Clothing',
#  'Jeans': 'Clothing',
#  'Blouse': 'Clothing',
#  'Skirt': 'Clothing',
#  'Sweater': 'Clothing',
#  'Dress': 'Clothing',
#  'Sunglasses': 'Accessories',
#  'Gloves': 'Accessories',
#  'Jewelry': 'Accessories',
#  'Hat': 'Accessories',
#  'Handbag': 'Accessories',
#  'Backpack': 'Accessories',
#  'Belt': 'Accessories',
#  'Scarf': 'Accessories',
#  'Bag': 'Accessories',
#  'Laptop': 'Electronics',
#  'Phone': 'Electronics',
#  'Headphones': 'Electronics',
#  'Watch': 'Electronics',
#  'Shoes': 'Footwear',
#  'Sandals': 'Footwear',
#  'Sneakers': 'Footwear',
#  'Boots': 'Footwear',
#  'Coat': 'Outerwear',
#  'Jacket': 'Outerwear'}

# %%
df['Category']=df['Item Purchased'].map(correct_mapping)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %% [markdown]
# # Handle Null Values

# %% [markdown]
# # Size

# %%
# Size 
df['Size'].unique()
# Out:
# array(['XL', 'M', 'L', 'S', nan], dtype=object)

# %%
df.groupby('Category')['Size'].unique() # check in categories where size exist
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Remove Size from Electronics
df.loc[df['Category']=='Electronics','Size']='Not Applicable'

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Remove Size from Accessories
df.loc[df['Category']=='Accessories','Size']='Free Size'

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Remove Size from Footwear
df.loc[df['Category']=='Footwear','Size']='Not Available'

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear          [Not Available]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Remove Size from Clothing
df.loc[(df['Category']=='Clothing') &(df['Size'].isnull()),'Size']=df[df['Category']=='Clothing']['Size'].mode()[0]

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories         [Free Size]
# Clothing          [XL, M, S, L]
# Electronics    [Not Applicable]
# Footwear        [Not Available]
# Outerwear         [XL, L, S, M]
# Name: Size, dtype: object

# %% [markdown]
# # Review Rating

# %%
df.groupby('Item Purchased')['Review Rating'].mean()
# Out:
# Item Purchased
# Backpack      3.758333
# Bag           3.168539
# Belt          3.762963
# Blouse        3.677647
# Boots         3.813194
# Coat          3.721875
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.771975
# Hat           3.796753
# Headphones    3.075949
# Hoodie        3.716779
# Jacket        3.761446
# Jeans         3.651969
# Jewelry       3.761850
# Laptop        3.191176
# Pants         3.720833
# Phone         2.939024
# Sandals       3.837037
# Scarf         3.702564
# Shirt         3.427273
# Shoes         3.546154
# Shorts        3.722981
# Skirt         3.779747
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.745679
# Sweater       3.768712
# T-shirt       3.790541
# Watch         3.100000
# Name: Review Rating, dtype: float64

# %%
# Filling Null value in Review rating
df['Review Rating']=df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'] .transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# 4                   80.0         Alabama  Free Size  Yellow  Spring
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0            3.2                  No        Standard               No
# 1            3.9                 Yes   Free Shipping              Yes
# 2            3.1                  No  2-Day Shipping               No
# 3            4.2                  No    Store Pickup               No
# 4            3.6                  No    Store Pickup               No
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                36.0           Cash                 Weekly
# 1                20.0     Debit Card              Quarterly
# 2                18.0           Cash                Monthly
# 3                25.0           Cash               Annually
# 4                17.0    Credit Card                 Weekly

# %% [markdown]
# # Previous Purchases

# %%
# Filing Previous Purchases with Zero
df['Previous Purchases']=df['Previous Purchases'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# # Purchase Amount (USD)

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack       60.111111
# Bag           735.773625
# Belt           59.993902
# Blouse         60.802326
# Boots          62.616438
# Coat           57.851852
# Dress          62.168675
# Gloves         60.550000
# Handbag        57.987261
# Hat            60.787097
# Headphones    831.344565
# Hoodie         58.059603
# Jacket         56.777108
# Jeans          60.456693
# Jewelry        59.011494
# Laptop        805.502027
# Pants          59.005848
# Phone         734.477349
# Sandals        57.527607
# Scarf          61.157233
# Shirt         279.935608
# Shoes         276.343790
# Shorts         60.073620
# Skirt          59.723270
# Sneakers       59.551724
# Socks          58.188679
# Sunglasses     59.975610
# Sweater        57.638554
# T-shirt        63.093333
# Watch         685.231471
# Name: Purchase Amount (USD), dtype: float64

# %%
# Filling Null value in Purchase Amount (USD)
df['Purchase Amount (USD)']=df['Purchase Amount (USD)'].fillna(df.groupby('Item Purchased')['Purchase Amount (USD)'] .transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# # Checking Duplicates Values

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df[df.duplicated()]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 886          2834   43  Female          Jeans     Clothing
# 1402         1621   25    Male            Hat  Accessories
# 1509          974   60    Male         Jacket    Outerwear
# 1600         2135   55    Male        Sandals     Footwear
# 1665         1846   51    Male        Sandals     Footwear
# 1797         3639   40  Female       Backpack  Accessories
# 1870         3456   49  Female        T-shirt     Clothing
# 2033         1812   42    Male           Belt  Accessories
# 2113         3040   59  Female         Blouse     Clothing
# 2226         1371   27    Male          Scarf  Accessories
# 2358         2977   30  Female           Coat    Outerwear
# 2447         2678   45  Female         Shorts     Clothing
# 2630          992   20    Male         Shorts     Clothing
# 2642         1566   58    Male     Sunglasses  Accessories
# 2739         2227   22    Male          Shirt     Clothing
# 2740         3487   51  Female         Shorts     Clothing
# 2800         2069   70    Male        Jewelry  Accessories
# 2905         2158   41    Male        Handbag  Accessories
# 2922         3334   55  Female          Jeans     Clothing
# 3036          258   20    Male        Handbag  Accessories
# 3065         3887   37  Female        Jewelry  Accessories
# 3185         1609   26    Male        Sandals     Footwear
# 3357         3091   29  Female          Shirt     Clothing
# 3390          603   37    Male          Shoes     Footwear
# 3538         1698   36    Male          Shirt     Clothing
# 3683         1209   20    Male          Boots     Footwear
# 3698          172   29    Male         Shorts     Clothing
# 3742          323   41    Male           Belt  Accessories
# 3810         2429   65    Male        T-shirt     Clothing
# 3843          615   68    Male        Jewelry  Accessories
# 3961         2558   70    Male         Shorts     Clothing
# 3987         3507   18  Female          Shirt     Clothing
# 4050         3287   45  Female         Jacket    Outerwear
# 4059          227   29    Male          Shoes     Footwear
# 4131         2642   25    Male     Sunglasses  Accessories
# 4183         1523   38    Male         Shorts     Clothing
# 4330         3716   63  Female     Sunglasses  Accessories
# 4390         3846   58  Female        Sweater     Clothing
# 4445         3644   53  Female          Scarf  Accessories
# 4468          473   20    Male          Jeans     Clothing
# 4513         1317   28    Male           Belt  Accessories
# 4558         3339   29  Female          Skirt     Clothing
# 4595         3577   29  Female          Boots     Footwear
# 4664         2689   53  Female        Handbag  Accessories
# 4717         2800   23  Female        T-shirt     Clothing
# 4735         2182   22    Male        Handbag  Accessories
# 4841         2622   48    Male          Shoes     Footwear
# 4887         3875   70  Female        Sweater     Clothing
# 4901         1060   22    Male         Jacket    Outerwear
# 5037         3439   26  Female          Shirt     Clothing
#
#       Purchase Amount (USD)        Location           Size      Color  Season  \
# 886                    56.0        Arkansas              M       Teal    Fall
# 1402                   47.0        Virginia      Free Size   Charcoal  Winter
# 1509                   75.0        Colorado              M       Teal    Fall
# 1600                   41.0        Virginia  Not Available     Maroon  Winter
# 1665                   78.0        Delaware  Not Available     Orange  Winter
# 1797                   20.0          Kansas      Free Size      Olive  Spring
# 1870                   89.0            Ohio              M     Orange    Fall
# 2033                   77.0       Wisconsin      Free Size       Blue  Summer
# 2113                   48.0         Alabama              L       Blue  Spring
# 2226                   67.0         Montana      Free Size      Peach  Summer
# 2358                   97.0        Nebraska              M     Silver  Summer
# 2447                   43.0     Connecticut              L      Olive  Spring
# 2630                   97.0       Wisconsin             XL      White  Spring
# 2642                   93.0           Idaho      Free Size      Peach    Fall
# 2739                   72.0        Missouri              L       Blue  Spring
# 2740                   89.0  North Carolina              L   Charcoal  Winter
# 2800                   81.0         Vermont      Free Size      Black  Summer
# 2905                   68.0     Mississippi      Free Size  Turquoise  Winter
# 2922                   35.0       Minnesota              M     Violet  Spring
# 3036                   53.0   West Virginia      Free Size        Red  Summer
# 3065                   92.0            Iowa      Free Size      Brown  Summer
# 3185                   58.0        Nebraska  Not Available       Cyan    Fall
# 3357                   36.0           Texas              M      Peach  Summer
# 3390                   58.0          Oregon  Not Available   Lavender  Summer
# 3538                   87.0  South Carolina              L   Lavender    Fall
# 3683                  100.0       Wisconsin  Not Available        Red  Winter
# 3698                   35.0        Virginia              M       Blue  Summer
# 3742                   95.0       Tennessee      Free Size       Cyan  Winter
# 3810                   38.0           Idaho              M     Violet  Spring
# 3843                   85.0           Idaho      Free Size   Lavender  Winter
# 3961                   23.0        Oklahoma              L       Cyan  Spring
# 3987                   57.0        Illinois              L      Olive  Winter
# 4050                   67.0        Illinois              L       Pink  Winter
# 4059                   74.0           Texas  Not Available     Violet  Spring
# 4131                   60.0         Vermont      Free Size      Olive  Winter
# 4183                   72.0       Tennessee              L     Yellow  Spring
# 4330                   34.0        Nebraska      Free Size     Orange    Fall
# 4390                   52.0      California              M      Green  Winter
# 4445                   96.0       Tennessee      Free Size    Magenta    Fall
# 4468                   39.0         Georgia              L       Gray  Winter
# 4513                   32.0        Arkansas      Free Size   Lavender  Spring
# 4558                   94.0       Minnesota              L      White  Winter
# 4595                   24.0           Maine  Not Available     Yellow  Spring
# 4664                   63.0   West Virginia      Free Size  Turquoise  Spring
# 4717                   89.0           Maine              L       Pink  Spring
# 4735                   63.0          Hawaii      Free Size      Black    Fall
# 4841                   46.0           Maine  Not Available      Beige  Winter
# 4887                   54.0          Nevada             XL      Beige  Summer
# 4901                   34.0  North Carolina              M      Beige  Winter
# 5037                   71.0        Kentucky              M     Violet    Fall
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 886        3.300000                  No   Free Shipping               No
# 1402       3.100000                  No  2-Day Shipping              Yes
# 1509       3.500000                 Yes  2-Day Shipping              Yes
# 1600       2.900000                  No        Standard               No
# 1665       2.800000                  No  2-Day Shipping               No
# 1797       4.600000                  No         Express               No
# 1870       4.700000                  No        Standard               No
# 2033       3.600000                  No        Standard               No
# 2113       3.200000                  No    Next Day Air               No
# 2226       3.702564                  No  2-Day Shipping              Yes
# 2358       2.800000                  No         Express               No
# 2447       3.800000                  No    Next Day Air               No
# 2630       2.700000                 Yes        Standard              Yes
# 2642       4.200000                  No   Free Shipping              Yes
# 2739       4.800000                  No    Store Pickup               No
# 2740       4.900000                  No        Standard               No
# 2800       3.900000                  No    Store Pickup               No
# 2905       4.000000                  No    Next Day Air               No
# 2922       4.200000                  No         Express               No
# 3036       4.500000                 Yes         Express              Yes
# 3065       3.900000                  No         Express               No
# 3185       4.600000                  No    Next Day Air              Yes
# 3357       4.900000                  No    Store Pickup               No
# 3390       4.200000                 Yes    Next Day Air              Yes
# 3538       3.500000                  No    Next Day Air               No
# 3683       3.813194                  No  2-Day Shipping              Yes
# 3698       3.600000                 Yes    Store Pickup              Yes
# 3742       3.000000                 Yes        Standard              Yes
# 3810       4.400000                  No    Next Day Air               No
# 3843       4.000000                 Yes        Standard              Yes
# 3961       3.900000                  No        Standard               No
# 3987       3.700000                  No  2-Day Shipping               No
# 4050       5.000000                  No         Express               No
# 4059       3.300000                 Yes   Free Shipping              Yes
# 4131       2.700000                  No    Next Day Air               No
# 4183       4.800000                  No   Free Shipping              Yes
# 4330       3.400000                  No   Free Shipping               No
# 4390       4.900000                  No        Standard               No
# 4445       3.200000                  No        Standard               No
# 4468       3.900000                 Yes   Free Shipping              Yes
# 4513       4.600000                  No        Standard              Yes
# 4558       2.900000                  No  2-Day Shipping               No
# 4595       3.000000                  No         Express               No
# 4664       2.900000                  No  2-Day Shipping               No
# 4717       3.900000                  No   Free Shipping               No
# 4735       3.200000                  No   Free Shipping               No
# 4841       3.000000                  No         Express               No
# 4887       3.900000                  No  2-Day Shipping               No
# 4901       2.500000                  No        Standard              Yes
# 5037       3.000000                  No    Store Pickup               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 886                 19.0           Cash                Monthly
# 1402                27.0         PayPal         Every 3 Months
# 1509                30.0  Bank Transfer              Quarterly
# 1600                35.0    Credit Card            Fortnightly
# 1665                39.0  Bank Transfer              Quarterly
# 1797                50.0         PayPal              Bi-Weekly
# 1870                13.0          Venmo               Annually
# 2033                33.0  Bank Transfer               Annually
# 2113                31.0         PayPal              Bi-Weekly
# 2226                41.0  Bank Transfer         Every 3 Months
# 2358                28.0           Cash            Fortnightly
# 2447                 6.0         PayPal         Every 3 Months
# 2630                40.0  Bank Transfer              Bi-Weekly
# 2642                48.0         PayPal               Annually
# 2739                28.0           Cash               Annually
# 2740                 6.0         PayPal                 Weekly
# 2800                44.0          Venmo                Monthly
# 2905                41.0          Venmo            Fortnightly
# 2922                 3.0         PayPal                Monthly
# 3036                 5.0    Credit Card              Quarterly
# 3065                40.0     Debit Card              Quarterly
# 3185                12.0  Bank Transfer              Bi-Weekly
# 3357                15.0  Bank Transfer              Quarterly
# 3390                10.0           Cash         Every 3 Months
# 3538                48.0    Credit Card         Every 3 Months
# 3683                 8.0     Debit Card               Annually
# 3698                 4.0    Credit Card                 Weekly
# 3742                47.0    Credit Card                Monthly
# 3810                34.0     Debit Card               Annually
# 3843                21.0    Credit Card              Bi-Weekly
# 3961                17.0         PayPal            Fortnightly
# 3987                12.0           Cash            Fortnightly
# 4050                 4.0          Venmo            Fortnightly
# 4059                 5.0         PayPal                Monthly
# 4131                20.0  Bank Transfer         Every 3 Months
# 4183                 5.0     Debit Card                Monthly
# 4330                 2.0  Bank Transfer                Monthly
# 4390                46.0          Venmo               Annually
# 4445                47.0     Debit Card               Annually
# 4468                 3.0  Bank Transfer              Quarterly
# 4513                14.0     Debit Card              Bi-Weekly
# 4558                46.0    Credit Card                Monthly
# 4595                12.0          Venmo              Bi-Weekly
# 4664                18.0    Credit Card         Every 3 Months
# 4717                 9.0  Bank Transfer         Every 3 Months
# 4735                32.0  Bank Transfer              Bi-Weekly
# 4841                21.0  Bank Transfer               Annually
# 4887                33.0    Credit Card              Bi-Weekly
# 4901                25.0     Debit Card                Monthly
# 5037                33.0    Credit Card                Monthly

# %%
# Deleting Duplicates Value
df=df.drop_duplicates(subset=['Customer ID'],keep='first')

# %%
len(df)
# Out:
# 5000

# %% [markdown]
# # Renaming the Headers

# %%
df.columns=df.columns.str.replace(" ","_")
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
#Rename purchase_amount_(usd) to purchase_amount
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# # Connect To SQL Server

# %%
# !pip install pyodbc sqlalchemy
# Out:
# Requirement already satisfied: pyodbc in c:\users\dell\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: sqlalchemy in c:\users\dell\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\dell\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\dell\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Connect MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Kamal@1224",
    database="Cleandata_db"
)

print("✅ Successfully Connected!")

# SQLAlchemy Engine
engine = create_engine(
    "mysql+mysqlconnector://root:Kamal%401224@localhost/Cleandata_db"
)

# Cursor
mycursor = mydb.cursor()

# Show tables
mycursor.execute("SHOW TABLES")

for table in mycursor:
    print(table)
# Out:
# ✅ Successfully Connected!
# ('customer_behaviour_analysis',)

# %%
table_name = "customer_behaviour_analysis"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"✅ Data successfully loaded into table '{table_name}'")
# Out:
# ✅ Data successfully loaded into table 'customer_behaviour_analysis'

# %%
df.head(28)
# Out:
#     customer_id  age  gender item_purchased     category  purchase_amount  \
# 0          2701   22  Female        T-shirt     Clothing        68.000000
# 1           521   51    Male     Sunglasses  Accessories        84.000000
# 2          3157   18  Female          Shirt     Clothing        50.000000
# 3          1687   22    Male         Gloves  Accessories        75.000000
# 4          2929   40  Female        Jewelry  Accessories        80.000000
# 5          3583   23  Female         Shorts     Clothing        41.000000
# 6          1135   62    Male        T-shirt     Clothing        81.000000
# 7          1411   61    Male            Hat  Accessories        93.000000
# 8           113   37    Male         Gloves  Accessories        65.000000
# 9           166   42    Male        Handbag  Accessories        60.000000
# 10         4568   35   Other          Shoes     Footwear       276.343790
# 11          947   46    Male           Coat    Outerwear        24.000000
# 12         4776   64   Other         Laptop  Electronics       884.040000
# 13         3855   57  Female        T-shirt     Clothing        20.000000
# 14          481   68    Male         Hoodie     Clothing        88.000000
# 15         3790   56  Female          Shirt     Clothing        75.000000
# 16         3617   42  Female         Hoodie     Clothing        23.000000
# 17         2659   52  Female        Handbag  Accessories        47.000000
# 18         3725   30  Female         Gloves  Accessories        71.000000
# 19         2134   21    Male            Hat  Accessories        34.000000
# 20         4256   70    Male          Phone  Electronics       734.477349
# 21          833   58    Male         Jacket    Outerwear        80.000000
# 22         1106   33    Male        T-shirt     Clothing        83.000000
# 23         3047   60  Female          Shoes     Footwear        49.000000
# 24         4685   68   Other          Phone  Electronics      1032.090000
# 25         1612   41    Male          Pants     Clothing        26.000000
# 26         4289   34  Female          Phone  Electronics      1282.440000
# 27         3552   66  Female         Gloves  Accessories        31.000000
#
#           location            size    color  season  review_rating  \
# 0       California              XL    Olive  Winter       3.200000
# 1   South Carolina       Free Size    White  Spring       3.900000
# 2          Montana               M    Black  Winter       3.100000
# 3         Illinois       Free Size      Red    Fall       4.200000
# 4          Alabama       Free Size   Yellow  Spring       3.600000
# 5       California               S    Beige  Summer       3.400000
# 6        Wisconsin               M    Brown  Summer       3.790541
# 7        Tennessee       Free Size   Purple  Summer       4.000000
# 8          Florida       Free Size      Red  Spring       4.300000
# 9         Kentucky       Free Size   Yellow  Winter       2.800000
# 10         Phoenix   Not Available     Blue  Autumn       3.546154
# 11    Pennsylvania              XL     Blue  Spring       2.800000
# 12     Los Angeles  Not Applicable    Black  Spring       3.191176
# 13         Florida               M    Black  Spring       4.200000
# 14         Vermont               M     Gray  Summer       4.800000
# 15    North Dakota               M  Magenta  Summer       3.800000
# 16       Wisconsin               L   Purple  Winter       3.300000
# 17            Ohio       Free Size   Indigo  Summer       3.200000
# 18        Colorado       Free Size    Green  Winter       3.100000
# 19           Maine       Free Size    Olive  Summer       3.800000
# 20     Los Angeles  Not Applicable    Green  Autumn       2.939024
# 21      California               L     Blue    Fall       2.500000
# 22   Massachusetts               S    Olive  Spring       3.000000
# 23    Pennsylvania   Not Available    White  Spring       3.200000
# 24         Phoenix  Not Applicable    Black  Summer       2.939024
# 25        Arkansas               L   Yellow  Winter       4.500000
# 26        New York  Not Applicable      Red  Autumn       2.939024
# 27         Montana       Free Size    Black  Spring       2.600000
#
#    subscription_status   shipping_type discount_applied  previous_purchases  \
# 0                   No        Standard               No                36.0
# 1                  Yes   Free Shipping              Yes                20.0
# 2                   No  2-Day Shipping               No                18.0
# 3                   No    Store Pickup               No                25.0
# 4                   No    Store Pickup               No                17.0
# 5                   No  2-Day Shipping               No                15.0
# 6                   No         Express              Yes                 2.0
# 7                   No    Store Pickup              Yes                18.0
# 8                  Yes   Free Shipping              Yes                28.0
# 9                  Yes    Store Pickup              Yes                 7.0
# 10                  No         Express              Yes                41.0
# 11                 Yes    Next Day Air              Yes                 4.0
# 12                  No         Express               No                 0.0
# 13                  No   Free Shipping               No                 4.0
# 14                 Yes        Standard              Yes                30.0
# 15                  No         Express               No                18.0
# 16                  No    Store Pickup               No                33.0
# 17                  No    Next Day Air               No                39.0
# 18                  No         Express               No                18.0
# 19                  No        Standard               No                13.0
# 20                 Yes        Standard              Yes                25.0
# 21                 Yes         Express              Yes                28.0
# 22                  No    Next Day Air              Yes                 6.0
# 23                  No    Store Pickup               No                25.0
# 24                  No         Express               No                 0.0
# 25                  No    Next Day Air              Yes                 6.0
# 26                  No         Express              Yes                36.0
# 27                  No    Store Pickup               No                20.0
#
#    payment_method frequency_of_purchases
# 0            Cash                 Weekly
# 1      Debit Card              Quarterly
# 2            Cash                Monthly
# 3            Cash               Annually
# 4     Credit Card                 Weekly
# 5          PayPal               Annually
# 6           Venmo         Every 3 Months
# 7      Debit Card               Annually
# 8          PayPal              Bi-Weekly
# 9            Cash                Monthly
# 10    Credit Card                Monthly
# 11         PayPal              Quarterly
# 12    Credit Card              Quarterly
# 13          Venmo               Annually
# 14     Debit Card              Bi-Weekly
# 15  Bank Transfer         Every 3 Months
# 16     Debit Card            Fortnightly
# 17         PayPal                Monthly
# 18  Bank Transfer               Annually
# 19  Bank Transfer               Annually
# 20           Cash                 Weekly
# 21           Cash              Bi-Weekly
# 22          Venmo         Every 3 Months
# 23           Cash         Every 3 Months
# 24         PayPal                Monthly
# 25     Debit Card                Monthly
# 26         PayPal                 Weekly
# 27          Venmo                 Weekly
